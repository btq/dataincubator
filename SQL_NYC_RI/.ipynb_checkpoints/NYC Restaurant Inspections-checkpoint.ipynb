# %%
import csv
import datetime as dt
import pandas as pd
import numpy as np
import os

log_file = "nyc_inspection_data%sWebExtract.txt"%os.sep
data = pd.io.parsers.read_csv(log_file,sep=',',quotechar='"',header=0,low_memory=False)
data.head()
# Out:
#       CAMIS                             DBA  BORO    BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP     2  1007
# 1  30112340                         WENDY'S     3         469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT     1         351
# 3  40356483              WILKEN'S FINE FOOD     3  7114
# 4  30191841  DJ REYNOLDS PUB AND RESTAURANT     1         351
#
#                                               STREET  ZIPCODE       PHONE  \
# 0  MORRIS PARK AVE                               ...    10462  7188924968
# 1                                    FLATBUSH AVENUE    11225  7182875005
# 2                                     WEST 57 STREET    10019  2122452912
# 3                   AVENUE U                            11234  7184443838
# 4                                     WEST 57 STREET    10019  2122452912
#
#    CUISINECODE             INSPDATE ACTION VIOLCODE  SCORE CURRENTGRADE  \
# 0            8  2014-03-03 00:00:00      D      10F      2            A
# ...

# %%
topzips = data.ZIPCODE.value_counts()
sigtopzips = topzips[topzips>100]

#return [("11201", 21.9060928719313812, 0.179441607823702, 6762)] * 183
otuple=[]
for z in sigtopzips.index:
    zdat = data[data["ZIPCODE"]==z]["SCORE"]
    zdat = zdat[zdat>=0]
    zmn = np.nanmean(zdat)
    n = len(zdat)-sum(np.isnan(zdat))  
    zse = np.nanstd(zdat) / np.sqrt(n)
    otuple.append(('%i' % z,zmn,zse,n))
otuple
# Out:
# [('10003', 22.513680430879713, 0.12740552502858005, 13925),
#  ('10019', 21.450097847358123, 0.12933890245852794, 12264),
#  ('10036', 22.437559996509293, 0.14423977944901148, 11459),
#  ('10013', 23.924642512501098, 0.15068531105908781, 11399),
#  ('10002', 24.300598926063611, 0.17223241067175488, 9684),
#  ('10022', 22.01130691657329, 0.15562048811436416, 9817),
#  ('10011', 21.424066571772691, 0.14279642239257179, 9133),
#  ('10016', 22.788999783033194, 0.15321546067103245, 9218),
#  ('10014', 21.568042548271478, 0.14862423102747996, 8649),
#  ('10001', 20.871685002895195, 0.16171017581973024, 8635),
#  ('10012', 21.13908087789499, 0.14341137458174716, 8247),
#  ('11354', 26.462010098581391, 0.2104620996164536, 8318),
#  ('11372', 24.170565045992117, 0.19521820189808614, 7610),
#  ('10017', 22.44653594771242, 0.16922428872640263, 7650),
#  ('11220', 25.873787680209698, 0.19866982139211728, 7630),
#  ('11215', 21.440064794816415, 0.16512955820337147, 7408),
# ...

# %%
with open('nyc_inspect_avg_zipcode.csv', "w") as the_file:
    csv.register_dialect("custom", delimiter=",")
    writer = csv.writer(the_file, dialect="custom")
    writer.writerows(otuple)

# %% [markdown]
# I then imported this file into CartoDB

# %%
from IPython.display import HTML
HTML('<iframe src=http://cdb.io/1SlRDsP width=1000 height=750></iframe>')
# Out:
# <iframe src=http://cdb.io/1SlRDsP width=1000 height=750></iframe>

# %% [markdown]
# ###Score by borough
# I then looked at mean grade by borough. Here, I used the RI_Webextract_BigApps_Latest.xls file to see how to code the boroughs by name. There are five boroughs, but there is a sixth blank

# %%
otuple=[]
boro_names=["","MANHATTAN","THE BRONX","BROOKLYN","QUEENS","STATEN ISLAND"]
for b in np.arange(1,6):
    bdat = data[data["BORO"]==b]["SCORE"]
    #some -1s and 0s exist in the data, remove them.
    bdat = bdat[bdat>=0]
    bmn = np.nanmean(bdat)
    n = len(bdat)-sum(np.isnan(bdat))  
    bse = np.nanstd(bdat) / np.sqrt(n)
    otuple.append((boro_names[b],bmn,bse,n))
sorted(otuple,key=lambda b: b[1])
# Out:
# [('STATEN ISLAND', 20.965332669446692, 0.1069902543813078, 16067),
#  ('THE BRONX', 21.57383198069752, 0.07116924387758955, 45590),
#  ('BROOKLYN', 22.181739480744341, 0.044390474694205227, 116667),
#  ('MANHATTAN', 22.259562493258944, 0.033273874893593847, 203974),
#  ('QUEENS', 22.687262825776894, 0.045650268113624298, 115685)]

# %%
"""
  Return a list of the 75 tuples of the form
  `(cuisine, mean grade, stderr, number of inspections)`
  for each of the 75 cuisine types with at least 100 inspections.
  **Hint**: you will have to perform a join with the `boroughs` table.
  Sort the list in ascendig order by score.  Are the least sanitary and most 
  sanitary cuisine types surprising?
"""
#return [("French", 21.9985734664764622, 0.177094690841052, 7010)] * 75
cuis_file = "nyc_inspection_data%sCuisine.txt"%os.sep
cuis_data = pd.io.parsers.read_csv(cuis_file,sep=',',quotechar='"',header=0,low_memory=False)
merg_data = pd.merge(data,cuis_data,on='CUISINECODE',sort=False)

cd_counts = merg_data.CODEDESC.value_counts()
top_cd = cd_counts[cd_counts>=100]
otuple=[]
for c in top_cd.index:
    cdat = merg_data[merg_data["CODEDESC"]==c]["SCORE"]
    cmn = np.nanmean(cdat)
    n = len(cdat)-sum(np.isnan(cdat))  
    cse = np.nanstd(cdat) / np.sqrt(n)
    otuple.append((c,cmn,cse,n))
sorted(otuple,key=lambda b: b[1])
# Out:
# [('Hotdogs/Pretzels', 14.51923076923077, 0.99718007866706126, 156),
#  ('Soups & Sandwiches', 14.961199294532628, 0.40904617986974662, 567),
#  ('Ethiopian', 15.346153846153847, 0.42445782225432982, 286),
#  ('Donuts', 15.536336731338375, 0.14351584576610082, 6082),
#  ('Hotdogs', 15.5413870246085, 0.43889506978639414, 447),
#  ('Ice Cream, Gelato, Yogurt, Ices',
#   15.943380040034315,
#   0.19519253686850047,
#   3497),
#  ('Sandwiches', 16.438442211055275, 0.14546661489127341, 6368),
#  ('Juice, Smoothies, Fruit Salads',
#   16.8989898989899,
#   0.23828085890752101,
#   2574),
#  ('Caf\xe9/Coffee/Tea', 17.125518307681496, 0.10345270030595691, 14229),
#  ('Sandwiches/Salads/Mixed Buffet',
#   17.19119623655914,
#   0.22068714968259523,
#   2976),
#  ('Cajun', 17.214285714285715, 0.58685422227236173, 168),
#  ('Armenian', 17.233449477351915, 0.40830051859599903, 574),
#  ('Other', 17.392756083757781, 0.36491771672206941, 1767),
# ...

# %%
"""
  Which cuisines tend to have a disproportionate number of what which violations?
  Answering this question isn't easy becuase you have to think carefully about
  normalizations.

  1. More popular cuisine categories will tend to have more violations just 
  becuase they represent more restaurants.

  2. Similarly, some violations are more common.  For example, knowing that 
  "Equipment not easily movable or sealed to floor" is a common violation for 
  Chinese restuarants is not particularly helpful when it is a common violation
  for all restaurants.

  The right quantity is to look at is the conditional probability of a specific
  type of violation given a specific cuisine type and divide it by the 
  unconditional probability of the violation for the entire population.  Taking
  this ratio gives the right answer.  Return the 20 highest ratios.

  **Hint**:
  1. You might want to check out this 
  [Stackoverflow post](http://stackoverflow.com/questions/972877/calculate-frequency-using-sql).

  2. The definition of a violation changes with time.  For example, 10A can 
  mean two different things "Toilet facility not maintained ..." or "Vermin or 
  other live animal present ..." when things were prior to 2003.

  3. The ratios don't mean much when the number of violations of a given type 
  and for a specific category are not large (why not?).  Be sure to filter 
  these out.  We chose 100 as our cutoff.
"""

viol_file = "nyc_inspection_data%sViolation.txt"%os.sep
viol_data = pd.io.parsers.read_csv(viol_file,sep=',',quotechar='"',header=0,low_memory=False)

merg_data['INSPDT'] = merg_data.INSPDATE.apply(lambda x: dt.datetime.strptime(x.split()[0],'%Y-%m-%d'))
viol_data['STRTDT'] = viol_data.STARTDATE.apply(lambda x: dt.datetime.strptime(x.split()[0],'%Y-%m-%d'))
viol_data['ENDDT'] = viol_data.ENDDATE.apply(lambda x: dt.datetime.strptime(x.split()[0],'%Y-%m-%d'))

merg_data['VIOLDESC']=pd.Series(list(merg_data['VIOLCODE']),index=merg_data.index)

violcode_counts = merg_data.VIOLCODE.value_counts()
sigviolcode_counts = violcode_counts[violcode_counts>100]
for c,cnt in sigviolcode_counts.iteritems():
    logidx = merg_data['VIOLCODE']==c
    merg_data.loc[logidx,'VIOLDESC']=merg_data.loc[logidx,'INSPDT'].apply(LookupViolCode,args=(viol_data,c))
#    merg_data[merg_data['VIOLCODE']==c]['VIOLDESC'].

def LookupViolCode(insp_date,vdata,vcode):
    #print insp_date
    #print vcode
    vc_data=vdata[vdata["VIOLATIONCODE"]==vcode]
    vc_data_data=vc_data[(vc_data.STRTDT<insp_date) & (vc_data.ENDDT>insp_date)]
    return vc_data_data['VIOLATIONDESC'].get_values()[0]

cuis_viol_data = merg_data.groupby('CODEDESC')['VIOLDESC'].value_counts()
viol_counts = merg_data['VIOLDESC'].value_counts()
cuis_viol_thresh=cuis_viol_data[cuis_viol_data>100]

total_viol = sum(cuis_viol_data)
result = []
for i,v in cuis_viol_thresh.iteritems():
    cv_cnt = cuis_viol_data[i]
    v_cnt = sum(cuis_viol_data[:,i[1]])
    c_cnt = sum(cuis_viol_data[i[0],])
    cp_vc = cv_cnt/(c_cnt+0.0)
    p_v = v_cnt/(total_viol+0.0)   
    result.append((i,cp_vc/p_v,cv_cnt))
sorted(result,key=lambda b: b[1],reverse=True)[:20]
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-19-9a0ccac5691b> in <module>()
#      31
#      32 viol_file = "nyc_inspection_data%sViolation.txt"%os.sep
# ---> 33 viol_data = pd.io.parsers.read_csv(viol_file,sep=',',quotechar='"',header=0,low_memory=False)
#      34
#      35 merg_data['INSPDT'] = merg_data.INSPDATE.apply(lambda x: dt.datetime.strptime(x.split()[0],'%Y-%m-%d'))
#
# ...
